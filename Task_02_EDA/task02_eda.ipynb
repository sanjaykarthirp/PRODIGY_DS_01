# %%
import numpy as np

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (10, 6)

df = pd.read_csv("data/titanic.csv")

print("\nFirst 5 rows of the dataset:")
print(df.head())
print("\nDataset Info:")
print(df.info())

print("\nStatistical Summary:")
print(df.describe())
print("\nMissing Values:")
print(df.isnull().sum())
df["Age"].fillna(df["Age"].median(), inplace=True)
df["Embarked"].fillna(df["Embarked"].mode()[0], inplace=True)

if "Cabin" in df.columns:
    df.drop(columns=["Cabin"], inplace=True)

print("\nMissing Values After Cleaning:")
print(df.isnull().sum())
sns.countplot(x="Survived", data=df)
plt.title("Survival Count")
plt.show()

sns.countplot(x="Sex", data=df)
plt.title("Gender Distribution")
plt.show()

sns.countplot(x="Pclass", data=df)
plt.title("Passenger Class Distribution")
plt.show()
sns.histplot(df["Age"], bins=30, kde=True)
plt.title("Age Distribution")
plt.show()
sns.countplot(x="Sex", hue="Survived", data=df)
plt.title("Survival Based on Gender")
plt.show()

sns.countplot(x="Pclass", hue="Survived", data=df)
plt.title("Survival Based on Passenger Class")
plt.show()

sns.boxplot(x="Survived", y="Age", data=df)
plt.title("Age vs Survival")
plt.show()

plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

print("\nKey Observations:")
print("1. Female passengers had a higher survival rate than males.")
print("2. Passengers in 1st class showed better survival chances.")
print("3. Younger passengers had slightly higher survival probability.")
print("4. Higher fare values are positively correlated with survival.")

print("\nCleaned Dataset Preview:")
print(df.head())

print("\nTask-02 EDA Completed Successfully.")
# Out:
# First 5 rows of the dataset:
#    Survived  Pclass     Sex  Age  SibSp  Parch   Fare Embarked
# 0         0       3    male   22      1      0   7.25        S
# 1         1       1  female   38      1      0  71.28        C
# 2         1       3  female   26      0      0   7.92        S
# 3         0       1    male   35      1      0  53.10        S
# 4         1       2  female   27      0      0  10.50        S
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  7 non-null      int64
#  1   Pclass    7 non-null      int64
#  2   Sex       7 non-null      object
#  3   Age       7 non-null      int64
#  4   SibSp     7 non-null      int64
#  5   Parch     7 non-null      int64
#  6   Fare      7 non-null      float64
#  7   Embarked  7 non-null      object
# dtypes: float64(1), int64(5), object(2)
# ...

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
