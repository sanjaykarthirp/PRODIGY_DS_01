# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

print("Current Working Directory:")
print(os.getcwd())

file_path = "data/population.xlsx"

if not os.path.exists(file_path):
    print("ERROR: population.xlsx not found in data folder")
else:
    df = pd.read_excel(file_path)
    print("\nDataset Preview:")
    print(df)

    plt.figure()
    plt.hist(df["Age"], bins=6)
    plt.xlabel("Age")
    plt.ylabel("Number of People")
    plt.title("Age Distribution")
    plt.show()

    plt.figure()
    df["Gender"].value_counts().plot(kind="bar")
    plt.xlabel("Gender")
    plt.ylabel("Count")
    plt.title("Gender Distribution")
    plt.show()

    print("\nTask-01 completed successfully.")
# Out:
# Current Working Directory:
# d:\PRODIGY_DS_01
#
# Dataset Preview:
#    Age  Gender
# 0   18    Male
# 1   22  Female
# 2   25    Male
# 3   30  Female
# 4   35    Male
# 5   40  Female
# 6   45    Male
# 7   50  Female
# Task-01 completed successfully.
